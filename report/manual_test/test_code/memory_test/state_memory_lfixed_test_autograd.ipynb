# %%
from qoc.standard.constants import harmonic,transmon,coherent_state,Identity
from scipy.sparse import kron
import numpy as np
import sys
from qoc import grape_schroedinger_discrete
from qoc.standard import (TargetStateInfidelity,ControlNorm,ControlVariation,generate_save_file_path,
                          ForbidStates)
from qoc.standard import Adam
from scipy import signal
from qutip import coherent
from qoc.models.operationpolicy import OperationPolicy
from scipy import signal
import numpy as np
import matplotlib.pyplot as plt
# %reload_ext memory_profiler
import autograd.numpy as anp
from qoc import grape_schroedinger_discrete
from qoc.standard import (TargetStateInfidelity,
                          conjugate_transpose,
                          get_annihilation_operator,
                          get_creation_operator,
                          SIGMA_Z,
                          generate_save_file_path, )
from memory_profiler import profile
import numpy as np

from qutip import (qsave,qload)
import matplotlib.pyplot as plt
from scipy.sparse import dia_matrix
# %matplotlib inline
def simulation(fock,dim_c,dim_trans,w_c,w_t,anharmonicity,g,evolution_time,step,initial,max_con):
    asd,b_dag,b=transmon(w_01=w_t,anharmonicity=anharmonicity,H_size=dim_trans)


    a_dag,a=harmonic(dim_c)
    I_t=Identity(dim_trans)
    I_c=Identity(dim_c)
    H_trans = 1 / 2 * anharmonicity * np.dot(np.dot(b_dag, b),np.dot(b_dag,b)-I_t)
    H_trans=kron( H_trans,I_c, format="csc")

    H_0=g*kron(b,a_dag,format="csc")+g*kron(b_dag,a,format="csc")+H_trans
    H_control=[(kron(b,I_c)+kron(b_dag,I_c)),kron(1j*(b-b_dag),I_c),kron(np.dot(b_dag, b),I_c)]
    hamiltonian = lambda controls, time: (H_0
                                          + controls[0] * H_control[0]
                                          + controls[1] * H_control[1]
                                          + controls[2] * H_control[2])
    T_initial=np.zeros(dim_trans)
    T_initial[0]=1
    C_initial=np.zeros(dim_c)
    C_initial[0]=1
    C_final=np.zeros(dim_c)
    C_final[fock]=1
#    C_final=coherent_state(N,alpha)
    Initial_state=np.kron(T_initial,C_initial)
    Initial_state=Initial_state.reshape(1,Initial_state.shape[0],1)
    Target=np.kron(T_initial,C_final)
    Target=Target.reshape((1,Target.shape[0],1))
    CONTROL_COUNT = 4
    CONTROL_EVAL_COUNT = SYSTEM_EVAL_COUNT = step + 1
    ITERATION_COUNT = 1

    max_control_norms=max_con*np.ones(CONTROL_COUNT)
    cost_first = ControlVariation(control_count=CONTROL_COUNT,
                             control_eval_count=CONTROL_EVAL_COUNT,
                             cost_multiplier=0.01,
                             max_control_norms=max_control_norms*0.2,
                             order=1)
    cost_second = ControlVariation(control_count=CONTROL_COUNT,
                                  control_eval_count=CONTROL_EVAL_COUNT,
                                  cost_multiplier=0.001,
                                  max_control_norms=max_control_norms*0.05,
                                  order=1)

    COSTS = [TargetStateInfidelity(Target,cost_multiplier=1)]

    # Define output.
    LOG_ITERATION_STEP = 1

    manual_parameter={"control_hamiltonian":H_control,"manual_gradient_mode":True,"tol":1e-8}
    optimizer = Adam(beta_1=0.9, beta_2=0.999, clip_grads=None,
                     epsilon=1e-8, learning_rate=1e-3,
                     learning_rate_decay=None, operation_policy=OperationPolicy.CPU,
                     scale_grads=None)

    def Impose(control):
        control[0] = control[control.shape[0] - 1] = 0
        return control

    SAVE_PATH = "./out"
    SAVE_FILE_NAME = "fock"
    SAVE_FILE_PATH = generate_save_file_path(SAVE_FILE_NAME, SAVE_PATH)

    if fock < 2:
        H_0=H_0.toarray()
        for i in range(len(H_control)):
            H_control[i]=H_control[i].toarray()
        result = grape_schroedinger_discrete(CONTROL_COUNT, CONTROL_EVAL_COUNT,
                                         COSTS, evolution_time, hamiltonian,
                                         Initial_state, SYSTEM_EVAL_COUNT,
                                         complex_controls=False,
                                         initial_controls=initial,
                                         iteration_count=ITERATION_COUNT,
                                         log_iteration_step=LOG_ITERATION_STEP,min_error=0.1,
                                        max_control_norms=max_control_norms,
                                             impose_control_conditions=Impose,
                                       
                                             save_iteration_step=1,

                                         )
    else:
        result = grape_schroedinger_discrete(CONTROL_COUNT, CONTROL_EVAL_COUNT,
                                             COSTS, evolution_time, hamiltonian,
                                             Initial_state, SYSTEM_EVAL_COUNT,
                                             complex_controls=False,
                                             initial_controls=initial,
                                             iteration_count=ITERATION_COUNT,
                                             log_iteration_step=LOG_ITERATION_STEP, min_error=0.05,
                                             max_control_norms=max_control_norms,
                                             manual_parameter=manual_parameter,impose_control_conditions=Impose,
                                             save_iteration_step=1,
                                             )
    return result

# %%
pre=2*np.pi
N_=[10,30,50,70,90,110]
#totol number of time step
mem_ma_Nfixed=[[],[]]
#first is average value,secind is standard deivation
h_dim=100
for N in N_:
    mem_temp = %memit -r1 -i0.0001 -o simulation(1,h_dim,3,3.9*pre,3.5*pre,-0.225*pre,0.1*pre,50,N,None,5)
    mem_temp=np.array(mem_temp.mem_usage)
    mem_ma_Nfixed[0].append(np.average(mem_temp))
    mem_ma_Nfixed[1].append(np.std(mem_temp))
qsave(mem_ma_Nfixed[0],'state_memory_lfixed_autograd')
# Out:
# iter   |   total error  |    grads_l2
# =========================================
#   0    | 9.56975143e-01 | 8.92851985e-01
# peak memory: 396.23 MiB, increment: 224.39 MiB
# iter   |   total error  |    grads_l2
# =========================================
#   0    | 6.00760070e-01 | 2.39929806e+00
# peak memory: 729.89 MiB, increment: 536.61 MiB
# iter   |   total error  |    grads_l2
# =========================================
# Process MemTimer-4:
# Traceback (most recent call last):
#   File "/Users/apple/miniconda3/envs/python36/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/Users/apple/miniconda3/envs/python36/lib/python3.6/site-packages/memory_profiler.py", line 225, in run
#     stop = self.pipe.poll(self.interval)
#   File "/Users/apple/miniconda3/envs/python36/lib/python3.6/multiprocessing/connection.py", line 257, in poll
#     return self._poll(timeout)
#   File "/Users/apple/miniconda3/envs/python36/lib/python3.6/multiprocessing/connection.py", line 414, in _poll
#     r = wait([self], timeout)
#   File "/Users/apple/miniconda3/envs/python36/lib/python3.6/multiprocessing/connection.py", line 911, in wait
#     ready = selector.select(timeout)
#   File "/Users/apple/miniconda3/envs/python36/lib/python3.6/selectors.py", line 376, in select
#     fd_event_list = self._poll.poll(timeout)
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-949f90954469> in <module>
#       6 h_dim=100
#       7 for N in N_:
# ----> 8     mem_temp = get_ipython().run_line_magic('memit', '-r1 -i0.0001 -o simulation(1,h_dim,3,3.9*pre,3.5*pre,-0.225*pre,0.1*pre,50,N,None,5)')
#       9     mem_temp=np.array(mem_temp.mem_usage)
#      10     mem_ma_Nfixed[0].append(np.average(mem_temp))
#
# ~/miniconda3/envs/python36/lib/python3.6/site-packages/IPython/core/interactiveshell.py in run_line_magic(self, magic_name, line, _stack_depth)
#    2324                 kwargs['local_ns'] = sys._getframe(stack_depth).f_locals
#    2325             with self.builtin_trap:
# -> 2326                 result = fn(*args, **kwargs)
#    2327             return result
#    2328
#
# ~/miniconda3/envs/python36/lib/python3.6/site-packages/decorator.py in fun(*args, **kw)
#     230             if not kwsyntax:
#     231                 args, kw = fix(args, kw, sig)
# --> 232             return caller(func, *(extras + args), **kw)
#     233     fun.__name__ = func.__name__
#     234     fun.__doc__ = func.__doc__
#
# ~/miniconda3/envs/python36/lib/python3.6/site-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# ~/miniconda3/envs/python36/lib/python3.6/site-packages/memory_profiler.py in memit(self, line, cell)
#    1070                                timeout=timeout, interval=interval,
#    1071                                max_usage=True,
# -> 1072                                include_children=include_children)
#    1073             mem_usage.append(tmp)
#    1074
#
# ~/miniconda3/envs/python36/lib/python3.6/site-packages/memory_profiler.py in memory_usage(proc, interval, timeout, timestamps, include_children, multiprocess, max_usage, retval, stream, backend, max_iterations)
#     334             # Therefore, the whole process hangs indefinitely. Here, we are ensuring that the process gets killed!
#     335             try:
# --> 336                 returned = f(*args, **kw)
#     337                 parent_conn.send(0)  # finish timing
#     338                 ret = parent_conn.recv()
#
# ~/miniconda3/envs/python36/lib/python3.6/site-packages/memory_profiler.py in _func_exec(stmt, ns)
#     843     # helper for magic_memit, just a function proxy for the exec
#     844     # statement
# --> 845     exec(stmt, ns)
#     846
#     847
#
# <string> in <module>
#
# <ipython-input-1-fbe96bb8f469> in simulation(fock, dim_c, dim_trans, w_c, w_t, anharmonicity, g, evolution_time, step, initial, max_con)
#     105                                              impose_control_conditions=Impose,
#     106
# --> 107                                              save_iteration_step=1,
#     108
#     109                                          )
#
# ~/PycharmProjects/qoc/qoc/core/schroedingerdiscrete.py in grape_schroedinger_discrete(control_count, control_eval_count, costs, evolution_time, hamiltonian, initial_states, system_eval_count, complex_controls, cost_eval_step, impose_control_conditions, initial_controls, interpolation_policy, iteration_count, log_iteration_step, magnus_policy, max_control_norms, min_error, optimizer, save_file_path, save_intermediate_states, save_iteration_step, manual_parameter)
#     273     # Run the optimization.
#     274     pstate.optimizer.run(_esd_wrap, pstate.iteration_count, initial_controls,
# --> 275                          _esdj_wrap, args=(pstate, reporter, result))
#     276
#     277     return result
#
# ~/PycharmProjects/qoc/qoc/standard/optimizers/adam.py in run(self, function, iteration_count, initial_params, jacobian, args)
#     102         params = initial_params
#     103         for i in range(iteration_count):
# --> 104             grads, terminate = jacobian(params, *args)
#     105             if terminate:
#     106                 break
#
# ~/PycharmProjects/qoc/qoc/core/schroedingerdiscrete.py in _esdj_wrap(controls, pstate, reporter, result)
#     353         grads=grads+grads_pu
#     354     else :
# --> 355         error, grads = (ans_jacobian(_evaluate_schroedinger_discrete, 0)(controls, pstate, reporter))
#     356     # Autograd defines the derivative of a function of complex inputs as
#     357     # df_dz = du_dx - i * du_dy for z = x + iy, f(z) = u(x, y) + iv(x, y).
#
# ~/miniconda3/envs/python36/lib/python3.6/site-packages/autograd/wrap_util.py in nary_f(*args, **kwargs)
#      18             else:
#      19                 x = tuple(args[i] for i in argnum)
# ---> 20             return unary_operator(unary_f, x, *nary_op_args, **nary_op_kwargs)
#      21         return nary_f
#      22     return nary_operator
#
# ~/PycharmProjects/qoc/qoc/standard/utils/autogradutil.py in ans_jacobian(function, argnum)
#      27     ans_vspace = vspace(ans)
#      28     jacobian_shape = ans_vspace.shape + vspace(argnum).shape
# ---> 29     grads = list(map(vjp, ans_vspace.standard_basis()))
#      30     jacobian = np.reshape(np.stack(grads), jacobian_shape)
#      31     return ans, jacobian
#
# ~/miniconda3/envs/python36/lib/python3.6/site-packages/autograd/core.py in vjp(g)
#      12         def vjp(g): return vspace(x).zeros()
#      13     else:
# ---> 14         def vjp(g): return backward_pass(g, end_node)
#      15     return vjp, end_value
#      16
#
# ~/miniconda3/envs/python36/lib/python3.6/site-packages/autograd/core.py in backward_pass(g, end_node)
#      19     for node in toposort(end_node):
#      20         outgrad = outgrads.pop(node)
# ---> 21         ingrads = node.vjp(outgrad[0])
#      22         for parent, ingrad in zip(node.parents, ingrads):
#      23             outgrads[parent] = add_outgrads(outgrads.get(parent), ingrad)
#
# ~/miniconda3/envs/python36/lib/python3.6/site-packages/autograd/core.py in <lambda>(g)
#      76             vjp_0 = vjp_0_fun(ans, *args, **kwargs)
#      77             vjp_1 = vjp_1_fun(ans, *args, **kwargs)
# ---> 78             return lambda g: (vjp_0(g), vjp_1(g))
#      79         else:
#      80             vjps = [vjps_dict[argnum](ans, *args, **kwargs) for argnum in argnums]
#
# ~/miniconda3/envs/python36/lib/python3.6/site-packages/autograd/numpy/linalg.py in <lambda>(g)
#      41     updim = lambda x: x if x.ndim == a.ndim else x[...,None]
#      42     if argnum == 0:
# ---> 43         return lambda g: -_dot(updim(solve(T(a), g)), T(updim(ans)))
#      44     else:
#      45         return lambda g: solve(T(a), g)
#
# ~/miniconda3/envs/python36/lib/python3.6/site-packages/autograd/tracer.py in f_wrapped(*args, **kwargs)
#      46             return new_box(ans, trace, node)
#      47         else:
# ---> 48             return f_raw(*args, **kwargs)
#      49     f_wrapped.fun = f_raw
#      50     f_wrapped._is_autograd_primitive = True
#
# <__array_function__ internals> in einsum(*args, **kwargs)
#
# ~/miniconda3/envs/python36/lib/python3.6/site-packages/numpy/core/einsumfunc.py in einsum(*operands, **kwargs)
#    1354     # If no optimization, run pure einsum
#    1355     if optimize_arg is False:
# -> 1356         return c_einsum(*operands, **kwargs)
#    1357
#    1358     valid_einsum_kwargs = ['out', 'dtype', 'order', 'casting']
#
# KeyboardInterrupt:

# %%
pre=2*np.pi
N_=[10,30,50,70,90,110]
#totol number of time step
mem_ma_Nfixed=[[],[]]
#first is average value,secind is standard deivation
h_dim=100
for N in N_:
    mem_temp = %memit -r1 -i0.0001 -o simulation(2,h_dim,3,3.9*pre,3.5*pre,-0.225*pre,0.1*pre,50,N,None,5)
    mem_temp=np.array(mem_temp.mem_usage)
    mem_ma_Nfixed[0].append(np.average(mem_temp))
    mem_ma_Nfixed[1].append(np.std(mem_temp))
qsave(mem_ma_Nfixed[0],'state_memory_lfixed_manual')
# Out:
# iter   |   total error  |    grads_l2
# =========================================
#   0    | 9.69089783e-01 | 5.44177657e-01
# peak memory: 173.63 MiB, increment: 2.29 MiB
# iter   |   total error  |    grads_l2
# =========================================
#   0    | 9.02008642e-01 | 1.34440215e+00
# peak memory: 173.91 MiB, increment: 0.25 MiB
# iter   |   total error  |    grads_l2
# =========================================
# Process MemTimer-3:
#   File "/Users/apple/miniconda3/envs/python36/lib/python3.6/multiprocessing/connection.py", line 257, in poll
#     return self._poll(timeout)
# Traceback (most recent call last):
#   File "/Users/apple/miniconda3/envs/python36/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/Users/apple/miniconda3/envs/python36/lib/python3.6/site-packages/memory_profiler.py", line 225, in run
#     stop = self.pipe.poll(self.interval)
#   File "/Users/apple/miniconda3/envs/python36/lib/python3.6/multiprocessing/connection.py", line 414, in _poll
#     r = wait([self], timeout)
#   File "/Users/apple/miniconda3/envs/python36/lib/python3.6/multiprocessing/connection.py", line 911, in wait
#     ready = selector.select(timeout)
#   File "/Users/apple/miniconda3/envs/python36/lib/python3.6/selectors.py", line 376, in select
#     fd_event_list = self._poll.poll(timeout)
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-a176b42cbef3> in <module>
#       6 h_dim=100
#       7 for N in N_:
# ----> 8     mem_temp = get_ipython().run_line_magic('memit', '-r1 -i0.0001 -o simulation(2,h_dim,3,3.9*pre,3.5*pre,-0.225*pre,0.1*pre,50,N,None,5)')
#       9     mem_temp=np.array(mem_temp.mem_usage)
#      10     mem_ma_Nfixed[0].append(np.average(mem_temp))
#
# ~/miniconda3/envs/python36/lib/python3.6/site-packages/IPython/core/interactiveshell.py in run_line_magic(self, magic_name, line, _stack_depth)
#    2324                 kwargs['local_ns'] = sys._getframe(stack_depth).f_locals
#    2325             with self.builtin_trap:
# -> 2326                 result = fn(*args, **kwargs)
#    2327             return result
#    2328
#
# ~/miniconda3/envs/python36/lib/python3.6/site-packages/decorator.py in fun(*args, **kw)
#     230             if not kwsyntax:
#     231                 args, kw = fix(args, kw, sig)
# --> 232             return caller(func, *(extras + args), **kw)
#     233     fun.__name__ = func.__name__
#     234     fun.__doc__ = func.__doc__
#
# ~/miniconda3/envs/python36/lib/python3.6/site-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# ~/miniconda3/envs/python36/lib/python3.6/site-packages/memory_profiler.py in memit(self, line, cell)
#    1070                                timeout=timeout, interval=interval,
#    1071                                max_usage=True,
# -> 1072                                include_children=include_children)
#    1073             mem_usage.append(tmp)
#    1074
#
# ~/miniconda3/envs/python36/lib/python3.6/site-packages/memory_profiler.py in memory_usage(proc, interval, timeout, timestamps, include_children, multiprocess, max_usage, retval, stream, backend, max_iterations)
#     334             # Therefore, the whole process hangs indefinitely. Here, we are ensuring that the process gets killed!
#     335             try:
# --> 336                 returned = f(*args, **kw)
#     337                 parent_conn.send(0)  # finish timing
#     338                 ret = parent_conn.recv()
#
# ~/miniconda3/envs/python36/lib/python3.6/site-packages/memory_profiler.py in _func_exec(stmt, ns)
#     843     # helper for magic_memit, just a function proxy for the exec
#     844     # statement
# --> 845     exec(stmt, ns)
#     846
#     847
#
# <string> in <module>
#
# <ipython-input-1-fbe96bb8f469> in simulation(fock, dim_c, dim_trans, w_c, w_t, anharmonicity, g, evolution_time, step, initial, max_con)
#     118                                              max_control_norms=max_control_norms,
#     119                                              manual_parameter=manual_parameter,impose_control_conditions=Impose,
# --> 120                                              save_iteration_step=1,
#     121                                              )
#     122     return result
#
# ~/PycharmProjects/qoc/qoc/core/schroedingerdiscrete.py in grape_schroedinger_discrete(control_count, control_eval_count, costs, evolution_time, hamiltonian, initial_states, system_eval_count, complex_controls, cost_eval_step, impose_control_conditions, initial_controls, interpolation_policy, iteration_count, log_iteration_step, magnus_policy, max_control_norms, min_error, optimizer, save_file_path, save_intermediate_states, save_iteration_step, manual_parameter)
#     273     # Run the optimization.
#     274     pstate.optimizer.run(_esd_wrap, pstate.iteration_count, initial_controls,
# --> 275                          _esdj_wrap, args=(pstate, reporter, result))
#     276
#     277     return result
#
# ~/PycharmProjects/qoc/qoc/standard/optimizers/adam.py in run(self, function, iteration_count, initial_params, jacobian, args)
#     102         params = initial_params
#     103         for i in range(iteration_count):
# --> 104             grads, terminate = jacobian(params, *args)
#     105             if terminate:
#     106                 break
#
# ~/PycharmProjects/qoc/qoc/core/schroedingerdiscrete.py in _esdj_wrap(controls, pstate, reporter, result)
#     343     if pstate.manual_gradient_mode is True:
#     344         error=_evaluate_schroedinger_discrete(controls, pstate, reporter,pulse=False)
# --> 345         grads=manual_gradient(controls, pstate, reporter)
#     346         error_pu=0
#     347         grads_pu=0
#
# ~/PycharmProjects/qoc/qoc/core/schroedingerdiscrete.py in manual_gradient(controls, pstate, reporter)
#     489             for m in range(len(costs)):
#     490                 if costs[m].type=="non-control" :
# --> 491                     grads[system_eval_count - 1 - i][k] =grads[system_eval_count - 1 - i][k]+costs[m].gradient(-total_H,1j * dt * control_hamiltonian[k],pstate.tol)
#     492         for l in range(len((costs))):
#     493             if costs[l].type == "non-control":
#
# ~/PycharmProjects/qoc/qoc/standard/costs/targetstateinfidelity.py in gradient(self, A, E, tol)
#     133             if self.neglect_relative_phase == False:
#     134                 for i in range(self.state_count):
# --> 135                     b_state, new_state = block_fre(A, E, tol, self.back_states[i])
#     136                     self.new_state.append(new_state)
#     137                     grads = grads + self.cost_multiplier * (-2 * np.real(
#
# ~/PycharmProjects/qoc/qoc/standard/functions/convenience.py in block_fre(A, E, tol, state)
#     136     state = np.block([state0, state])
#     137
# --> 138     state = expm_multiply(c, state,u_d=tol)
#     139     new =state[HILBERT_SIZE:2*HILBERT_SIZE]
#     140     state = state[0:HILBERT_SIZE]
#
# ~/PycharmProjects/qoc/qoc/standard/functions/convenience.py in expm_multiply(A, B, u_d)
#     222     if tol is None:
#     223         tol =1e-16
# --> 224     s=get_s(A,B,tol)
#     225     F = B
#     226     c1 = overnorm(B)
#
# ~/PycharmProjects/qoc/qoc/standard/functions/convenience.py in get_s(A, b, tol)
#     197         while(1):
#     198             tol_power = np.ceil(np.log10(tol))
# --> 199             norm_A = overnorm(A)/s
#     200             norm_b= norm_state(b)
#     201             max_term_notation=np.floor(norm_A)
#
# ~/PycharmProjects/qoc/qoc/standard/functions/convenience.py in overnorm(A)
#     261         return _exact_inf_norm(A)
#     262     else:
# --> 263         return norm_two(A)
#     264 def norm_two(A):
#     265     if sci.sparse.isspmatrix(A):
#
# ~/PycharmProjects/qoc/qoc/standard/functions/convenience.py in norm_two(A)
#     265     if sci.sparse.isspmatrix(A):
#     266         A=csr_matrix(A).conjugate().transpose()
# --> 267         return np.sqrt(abs(eigs(A=A.dot(A),k=1,which='LM',return_eigenvectors=False)[0]))
#     268     else:
#     269         return np.linalg.norm(A)
#
# ~/miniconda3/envs/python36/lib/python3.6/site-packages/scipy/sparse/linalg/eigen/arpack/arpack.py in eigs(A, k, M, sigma, which, v0, ncv, maxiter, tol, return_eigenvectors, Minv, OPinv, OPpart)
#    1345     with _ARPACK_LOCK:
#    1346         while not params.converged:
# -> 1347             params.iterate()
#    1348
#    1349         return params.extract(return_eigenvectors)
#
# ~/miniconda3/envs/python36/lib/python3.6/site-packages/scipy/sparse/linalg/eigen/arpack/arpack.py in iterate(self)
#     731                                     self.tol, self.resid, self.v, self.iparam,
#     732                                     self.ipntr, self.workd, self.workl,
# --> 733                                     self.rwork, self.info)
#     734
#     735         xslice = slice(self.ipntr[0] - 1, self.ipntr[0] - 1 + self.n)
#
# KeyboardInterrupt:
